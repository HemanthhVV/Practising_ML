# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv("C:\\Users\\vvhem\\Downloads\\cap.csv")

# %%
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
df.rename(columns = {'per capita income (US$)':'TEST'}, inplace = True)

# %%
df.columns
# Out:
# Index(['year', 'TEST'], dtype='object')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.scatter(df.year,df.TEST,marker='*',color='yellow')
plt.xlabel("year")
plt.ylabel("Test_score")
# Out:
# Text(0, 0.5, 'Test_score')

# %%
plt.hist(df.TEST)
plt.xlabel("year")
plt.ylabel("Test_score")
# Out:
# Text(0, 0.5, 'Test_score')

# %%
plt.pie(df.TEST)
plt.xlabel("test_score")
# Out:
# Text(0.5, 0, 'test_score')

# %%
reg=linear_model.LinearRegression()
X=df[['year']]
y=df['TEST']
reg.fit(X,y)
# Out:
# LinearRegression()

# %%
reg.score(X,y)
# Out:
# 0.9719068955671568

# %%
from

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.scatter(df.year,df.TEST,marker='*',color='yellow')
plt.plot(df.year,reg.predict(X),color='cyan')
